# %%
import pandas as pd
import numpy as np
cwur_df = pd.read_csv('data.csv', delimiter=",")
shangai_df = pd.read_csv('shanghaiData.csv', delimiter=",")
times_df = pd.read_csv('timesData.csv', delimiter=",")
times_df[0:19]
# Out:
#    world_rank                                    university_name  \
# 0           1                                 Harvard University
# 1           2                 California Institute of Technology
# 2           3              Massachusetts Institute of Technology
# 3           4                                Stanford University
# 4           5                               Princeton University
# 5           6                            University of Cambridge
# 6           6                               University of Oxford
# 7           8                 University of California, Berkeley
# 8           9                            Imperial College London
# 9          10                                    Yale University
# 10         11              University of California, Los Angeles
# 11         12                              University of Chicago
# 12         13                           Johns Hopkins University
# ...

# %%
times_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   world_rank              2603 non-null   object
#  1   university_name         2603 non-null   object
#  2   country                 2603 non-null   object
#  3   teaching                2603 non-null   float64
#  4   international           2603 non-null   object
#  5   research                2603 non-null   float64
#  6   citations               2603 non-null   float64
#  7   income                  2603 non-null   object
#  8   total_score             2603 non-null   object
#  9   num_students            2544 non-null   object
#  10  student_staff_ratio     2544 non-null   float64
#  11  international_students  2536 non-null   object
#  12  female_male_ratio       2370 non-null   object
#  13  year                    2603 non-null   int64
# ...

# %% [markdown]
# Donne un aperçu de chaque fichier csv et décris en une phrase son contenu.
# --> Ce df nous donne de nombreuses informations sur chaque université en renseignant la qualité, le nombre de publications, l'influence et autres index. De même, chaque uni se voit attribué une note qui est sensée témoigner de sa qualité d'enseignements.

# %% [markdown]
# ### Quelles années sont prises en charge par chaque classement ?

# %%
#Création d'une array permettant d'appeller le classement que l'on veut, et permettant de faciliter les commandes qui se répetent.
classement = [shangai_df, cwur_df, times_df]
classement_str = ["shangai", "CWUR", "times"]
years_tab = []
i = 0
while i < len(classement):
        years_tab.append(classement[i]['year'].unique())
        i += 1
# print('Chaque classement prend en charge les années,', y,".")
i = 0
while i < len(classement_str):
    print ("Le classement", classement_str[i],"comporte les années : ",years_tab[i])
    i+= 1
# Out:
# Le classement shangai comporte les années :  [2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015]
# Le classement CWUR comporte les années :  [2012 2013 2014 2015]
# Le classement times comporte les années :  [2011 2012 2013 2014 2015 2016]

# %% [markdown]
# ### Combien d'universités sont prises en compte annuellement par chaque classement en moyenne ? Il s'agit ici de donner le nombre moyen d'universités prises en compte par chaque classement lors d'une année.

# %%
#Il suffit de faire une moyenne du nombre de répétion de chaque année dans la colonne years pour chaque uni. 
i = 0
mean_tab = []
while i < len(classement):
        mean_tab.append(round(classement[i]["year"].value_counts().mean()))
        i += 1
i = 0
while i < len(classement_str):
    print ("Chaque année, le classement", classement_str[i],"prend en compte",mean_tab[i],"universités en moyenne.")
    i+= 1
# Out:
# Chaque année, le classement shangai prend en compte 445 universités en moyenne.
# Chaque année, le classement CWUR prend en compte 550 universités en moyenne.
# Chaque année, le classement times prend en compte 434 universités en moyenne.

# %% [markdown]
# ## Quels sont les rankings obtenus par l'Université de Strabourg dans chacun des 3 classements disponibles ?

# %%
class_tab.append(classement[y]["world_rank"][i])
y = 0
p = []
yy = "Strasbourg"
while y < len(classement):
    i = 0 
    while i < len(classement[y]):
        if yy in (classement[y]["university_name"][i]):
            p.append(classement[2]["world_rank"][1])
        i += 1
    y += 1
print(p)


# type(classement[2]["world_rank"][3])
# u = []
# yy = "of Techno"
# if yy in classement[2]["university_name"][1]:
#     u.append(classement[2]["world_rank"][1])
# print (u)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [173], in <cell line: 5>()
#       6 i = 0
#       7 while i < len(classement[y]):
# ----> 8     if yy in (classement[y]["university_name"][i]):
#       9         p.append(classement[2]["world_rank"][1])
#      10     i += 1
#
# TypeError: argument of type 'float' is not iterable

# %% [markdown]
# Selon le classement du Times, quels sont les 20 meilleures universités en 2016 ? Quelle est la part d'universités américaines ?

# %% [markdown]
# Combien chaque pays possède d'universités dans le classement de Shanghai en 2015 ? Range la liste par ordre décroissant. Pense à t'aider de la table université - pays pour réaliser cette requête.

# %% [markdown]
# Quelles sont les universités françaises présentes dans le classement du Center for WUR ?

# %% [markdown]
# Quels pays ont les plus faibles ratios (Dépenses dans les Institutions du Supérieur (Privées et Publiques) en 2011) / Nombre d'universités dans le classement du Times en 2011 ? Range cette liste par ordre croissant.
